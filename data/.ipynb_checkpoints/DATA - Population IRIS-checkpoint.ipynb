# %% [markdown]
# ## IRIS

# %% [markdown]
# ### Typologie des IRIS
#
# sources: [Insee](https://www.insee.fr/fr/metadonnees/definition/c1523), [geoconcept]
# (https://fr.geoconcept.com/zone-iris)<br>
# <br>
# Les IRIS constituent chacun un « micro quartier », composé d'un ensemble **d'îlots contigus et homogènes**, regroupant **2000 habitants ou plus**.
#
# Chaque IRIS constitue un secteur communal de base, un « micro quartier » géographique et démographique homogène, clairement et durablement defini. Sur ce « maillon élémentaire » est pratiquée la collecte de données statistiques et démographiques. Ces données sont ensuite analysées et les résultats publiés par l'INSEE.
#
# La France compte 50 800 IRIS, dont 700 dans les DOM répartis comme suit :
#
# - 16 100 IRIS, dont 650 dans les DOM, issus du découpage des communes de plus de 10 000 habitants, et la plupart des communes de 5 000 à 10 000 habitants,
# - 34 800 IRIS, constitués par les communes non-découpées.
#
#
# Les IRIS se déclinent en trois types de zones :
#
# - **IRIS d'habitat (H)** : IRIS dont la population se situe entre 1 800 et 5 000 habitants ; ils sont homogènes quant au type d'habitat ;
# - **IRIS d'activité (A)**: IRIS regroupant plus de 1 000 salariés et comptent deux fois plus d'emplois salariés que de population résidente ;
# - **IRIS divers (D)**: IRIS de superficie importante à usage particulier (bois, parcs, zones portuaires...).
# - **IRIS autres (Z)**.<br>
# Plus de 92% des IRIS sont des IRIS d’habitat, 5% des IRIS d’activité.
#
#
# ### Code IRIS
# À chaque îlot est associé un code IRIS. Composé de 9 caractères. Il permet d'identifier de manière univoque un îlot. Les cinq premiers caractères du code IRIS correspondent au code Insee de la commune sur le territoire de laquelle est situé l'îlot.

# %% [markdown]
# ### Différentes bdd sur bases IRIS :
# - Population 2016
# - Couple, familles, ménages 2016
# - Logements 2016
# - Activités des résidents 2016
# - Revenus 2016
# <br>
# (Non pris en compte Diplômes et formation 2016.)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Population 2016 (IRIS) - France hors Mayotte
# infra-communales

# %%
# Population hors ménages![image.png](attachment:image.png)
varpopIR = pd.read_excel('IRIS_population/variable_struct-pop-2016-cIA.xlsx')
varpopIR
# Out:
#          VAR_ID                           VAR_LIB  \
# 0          IRIS                              IRIS
# 1           REG                            Région
# 2           DEP                       Département
# 3        UU2010                     Unité urbaine
# 4           COM                    Commune ou ARM
# ..          ...                               ...
# 79   P16_POP_FR      Pop Français en 2016 (princ)
# 80  P16_POP_ETR     Pop Etrangers en 2016 (princ)
# 81  P16_POP_IMM      Pop Immigrés en 2016 (princ)
# 82     P16_PMEN       Pop ménages en 2016 (princ)
# 83  P16_PHORMEN  Pop hors ménages en 2016 (princ)
#
#                                          VAR_LIB_LONG
# 0   Code du département suivi du numéro de commune...
# 1                                   Code de la région
# 2                                 Code du département
# 3   Code du département ou "00" pour les unités ur...
# 4   Code du département suivi du numéro de commune...
# ...

# %%
popIR = pd.read_excel('IRIS_population/base-ic-evol-struct-pop-2016-cIA.xls')

# %%
popIR.head(10)
# Out:
#         IRIS  REG DEP UU2010    COM                   LIBCOM  TRIRIS  \
# 0  010010000   84  01  01000  01001  L'Abergement-Clémenciat  ZZZZZZ
# 1  010020000   84  01  01000  01002    L'Abergement-de-Varey  ZZZZZZ
# 2  010040101   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# 3  010040102   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# 4  010040201   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# 5  010040202   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# 6  010050000   84  01  01000  01005      Ambérieux-en-Dombes  ZZZZZZ
# 7  010060000   84  01  01000  01006                  Ambléon  ZZZZZZ
# 8  010070000   84  01  01000  01007                 Ambronay  ZZZZZZ
# 9  010080000   84  01  01302  01008                 Ambutrix  ZZZZZZ
#
#   GRD_QUART                                       LIBIRIS TYP_IRIS  ...  \
# 0   0100100  L'Abergement-Clémenciat (commune non irisée)        Z  ...
# ...

# %% [markdown]
# ## Population
# - POP IRIS ÂGE CSP<br>
# **GEO** : IRIS / Libé commune ou ARM / Type d'IRIS<br>
# **Pop âge**: 0-14 / 15-29 / 30-44 / 45-59 / 60-74 / 75 +<br>
# **CSP +15 ans**: CS1 Agriculteur exploit. / CS2 Artisants, commerçants, Chef d'E. / CS3 Cadres Prof. Int. Sup. / CS4 Prof. Inter. / CS5 Employés / CS6 Ouvriers / CS7 Retraités / CS8 Autres sans activités pro.<br>
# <br>
# - POP IRIS ÂGE SEXE CSP<br>
# **GEO** : IRIS / Libé commune ou ARM / Type d'IRIS<br>
# **Pop homme âge**: 0-14 / 15-29 / 30-44 / 45-59 / 60-74 / 75 +<br>
# **Pop femme âge**: 0-14 / 15-29 / 30-44 / 45-59 / 60-74 / 75 +<br>
# **CSP homme +15 ans**: CS1 Agriculteur exploit. / CS2 Artisants, commerçants, Chef d'E. / CS3 Cadres Prof. Int. Sup. / CS4 Prof. Inter. / CS5 Employés / CS6 Ouvriers / CS7 Retraités / CS8 Autres sans activités pro.<br>
# **CSP femme +15 ans**: CS1 Agriculteur exploit. / CS2 Artisants, commerçants, Chef d'E. / CS3 Cadres Prof. Int. Sup. / CS4 Prof. Inter. / CS5 Employés / CS6 Ouvriers / CS7 Retraités / CS8 Autres sans activités pro.

# %%
popIR_drop = popIR[['IRIS', 'REG', 'DEP', 'UU2010', 'LIBCOM', 'GRD_QUART', 'LIBIRIS', 'TRIRIS', 'MODIF_IRIS', 'LAB_IRIS', 'P16_POP', 'P16_POP0002', 'P16_POP0305',
                                'P16_POP0610', 'P16_POP1117', 'P16_POP1824', 'P16_POP2539', 'P16_POP4054', 'P16_POP5564',
                                'P16_POP6579', 'P16_POP80P', 'P16_POP0019', 'P16_POP2064', 'P16_POP65P', 'P16_POPH', 'P16_H0019',
                                'P16_H2064', 'P16_H65P','P16_POPF', 'P16_F0019', 'P16_F2064', 'P16_F65P', 'C16_POP15P', 'C16_H15P', 'C16_H15P_CS1',
                                'C16_H15P_CS2', 'C16_H15P_CS3', 'C16_H15P_CS4', 'C16_H15P_CS5', 'C16_H15P_CS6', 'C16_H15P_CS7',
                                'C16_H15P_CS8', 'C16_F15P', 'C16_F15P_CS1', 'C16_F15P_CS2', 'C16_F15P_CS3', 'C16_F15P_CS4',
                                'C16_F15P_CS5', 'C16_F15P_CS6', 'C16_F15P_CS7', 'C16_F15P_CS8', 'P16_POP_FR', 'P16_POP_ETR', 'P16_POP_IMM',
                                'P16_PMEN', 'P16_PHORMEN']]

# %%
popIR_new = popIR.drop(columns=['REG', 'DEP', 'UU2010', 'COM', 'GRD_QUART', 'LIBIRIS','TRIRIS', 'MODIF_IRIS', 'LAB_IRIS', 'P16_POP', 'P16_POP0002', 'P16_POP0305',
                                'P16_POP0610', 'P16_POP1117', 'P16_POP1824', 'P16_POP2539', 'P16_POP4054', 'P16_POP5564',
                                'P16_POP6579', 'P16_POP80P', 'P16_POP0019', 'P16_POP2064', 'P16_POP65P', 'P16_POPH', 'P16_H0014', 'P16_H1529', 'P16_H3044',
                                'P16_H4559', 'P16_H6074', 'P16_H75P', 'P16_F0014', 'P16_F1529', 'P16_F3044', 'P16_F4559', 'P16_F6074', 'P16_F75P','P16_H0019',
                                'P16_H2064', 'P16_H65P','P16_POPF', 'P16_F0019', 'P16_F2064', 'P16_F65P', 'C16_POP15P', 'C16_H15P', 'C16_H15P_CS1',
                                'C16_H15P_CS2', 'C16_H15P_CS3', 'C16_H15P_CS4', 'C16_H15P_CS5', 'C16_H15P_CS6', 'C16_H15P_CS7',
                                'C16_H15P_CS8', 'C16_F15P', 'C16_F15P_CS1', 'C16_F15P_CS2', 'C16_F15P_CS3', 'C16_F15P_CS4',
                                'C16_F15P_CS5', 'C16_F15P_CS6', 'C16_F15P_CS7', 'C16_F15P_CS8', 'P16_POP_FR', 'P16_POP_ETR', 'P16_POP_IMM',
                                'P16_PMEN', 'P16_PHORMEN'])


popHFIR_new = popIR.drop(columns=['REG', 'DEP', 'UU2010', 'COM', 'GRD_QUART', 'LIBIRIS','TRIRIS', 'MODIF_IRIS', 'LAB_IRIS', 'P16_POP', 'P16_POP0002', 'P16_POP0305',
                                  'P16_POP0610', 'P16_POP1117', 'P16_POP1824', 'P16_POP2539', 'P16_POP4054', 'P16_POP5564',
                                  'P16_POP6579', 'P16_POP80P', 'P16_POP0014', 'P16_POP1529', 'P16_POP3044', 'P16_POP4559', 'P16_POP6074', 'P16_POP75P', 'P16_POP0019',
                                  'P16_POP2064', 'P16_POP65P', 'P16_POPH', 'P16_H0019',
                                  'P16_H2064', 'P16_H65P','P16_POPF', 'P16_F0019', 'P16_F2064', 'P16_F65P', 'C16_POP15P', 'C16_H15P', 'C16_F15P', 'C16_POP15P_CS1',
                                  'C16_POP15P_CS2', 'C16_POP15P_CS3', 'C16_POP15P_CS4', 'C16_POP15P_CS5', 'C16_POP15P_CS6', 'C16_POP15P_CS7',
                                  'C16_POP15P_CS8', 'P16_POP_FR', 'P16_POP_ETR', 'P16_POP_IMM',
                                  'P16_PMEN', 'P16_PHORMEN'])

# %%
popIR_new.head()
# Out:
#         IRIS                   LIBCOM TYP_IRIS  P16_POP0014  P16_POP1529  \
# 0  010010000  L'Abergement-Clémenciat        Z   161.000000   102.000000
# 1  010020000    L'Abergement-de-Varey        Z    55.000000    28.000000
# 2  010040101        Ambérieu-en-Bugey        H   319.155575   519.011004
# 3  010040102        Ambérieu-en-Bugey        H   706.686436   795.052938
# 4  010040201        Ambérieu-en-Bugey        H   801.240994   848.693971
#
#    P16_POP3044  P16_POP4559  P16_POP6074  P16_POP75P  C16_POP15P_CS1  \
# 0   132.000000   189.000000   125.000000   58.000000       15.000000
# 1    70.000000    37.000000    34.000000   19.000000        0.000000
# 2   346.937127   259.198657   295.470786  153.339057        0.000000
# 3   737.794854   607.335319   425.641161  273.699455        2.804736
# 4   732.298592   717.244067   591.336732  409.189232        0.000000
#
#    C16_POP15P_CS2  C16_POP15P_CS3  C16_POP15P_CS4  C16_POP15P_CS5  \
# ...

# %%
popIR_new.apply(lambda x: len(x.unique()))
# Out:
# IRIS              49637
# LIBCOM            33042
# TYP_IRIS              4
# P16_POP0014       41144
# P16_POP1529       40882
# P16_POP3044       41159
# P16_POP4559       41342
# P16_POP6074       41168
# P16_POP75P        40649
# C16_POP15P_CS1    21214
# C16_POP15P_CS2    34900
# C16_POP15P_CS3    35184
# C16_POP15P_CS4    38135
# C16_POP15P_CS5    38585
# C16_POP15P_CS6    38500
# C16_POP15P_CS7    39877
# C16_POP15P_CS8    38135
# dtype: int64

# %%
# popHFIR_new.apply(lambda x: len(x.unique()))

# %%
popIR_new.shape
# Out:
# (49637, 17)

# %% [markdown]
# ### Checking missing values
# No data are missing!

# %%
# popIR_new.isnull().sum()/len(popIR_new)*100
# popHFIR_new.isnull().sum()/len(popIR_new)*100

# %% [markdown]
# ### Focus on IRIS Type inhabitant --> H

# %%
popIR_new['TYP_IRIS'].unique()
# Out:
# array(['Z', 'H', 'A', 'D'], dtype=object)

# %% [markdown]
# Reminder:<br>
# - IRIS d'habitat (H) : IRIS dont la population se situe entre 1 800 et 5 000 habitants ; ils sont homogènes quant au type d'habitat ;
# - IRIS d'activité (A): IRIS regroupant plus de 1 000 salariés et comptent deux fois plus d'emplois salariés que de population résidente ;
# - IRIS divers (D): IRIS de superficie importante à usage particulier (bois, parcs, zones portuaires...).
# - IRIS autres (Z).

# %%
popIR_H_new = popIR_new[(popIR_new['TYP_IRIS'].values  == "H")] # habitant
#popIR_HA_new = popIR_new[(popIR_new.values  == "H") | (popIR_new.values  == "A")] # habitant activite
#popIR_A_new = popIR_new[(popIR_new.values  == "A")] 
popIR_H_new
# Out:
#             IRIS                    LIBCOM TYP_IRIS  P16_POP0014  P16_POP1529  \
# 2      010040101         Ambérieu-en-Bugey        H   319.155575   519.011004
# 3      010040102         Ambérieu-en-Bugey        H   706.686436   795.052938
# 4      010040201         Ambérieu-en-Bugey        H   801.240994   848.693971
# 5      010040202         Ambérieu-en-Bugey        H   964.211945   729.924215
# 32     010330101  Bellegarde-sur-Valserine        H   279.435503   237.734356
# ...          ...                       ...      ...          ...          ...
# 49631  974230201         Les Trois-Bassins        H   158.999910   153.224144
# 49632  974240101                    Cilaos        H   362.419006   242.622455
# 49633  974240102                    Cilaos        H   367.370085   284.191953
# 49634  974240103                    Cilaos        H   149.522595   128.728062
# 49635  974240104                    Cilaos        H   211.906195   183.189935
#
# ...

# %%
popHFIR_H_new = popHFIR_new[(popHFIR_new['TYP_IRIS'].values  == "H") | (popHFIR_new['TYP_IRIS'].values  == "A")]
popIR_H_new
# Out:
#             IRIS                    LIBCOM TYP_IRIS  P16_POP0014  P16_POP1529  \
# 2      010040101         Ambérieu-en-Bugey        H   319.155575   519.011004
# 3      010040102         Ambérieu-en-Bugey        H   706.686436   795.052938
# 4      010040201         Ambérieu-en-Bugey        H   801.240994   848.693971
# 5      010040202         Ambérieu-en-Bugey        H   964.211945   729.924215
# 32     010330101  Bellegarde-sur-Valserine        H   279.435503   237.734356
# ...          ...                       ...      ...          ...          ...
# 49631  974230201         Les Trois-Bassins        H   158.999910   153.224144
# 49632  974240101                    Cilaos        H   362.419006   242.622455
# 49633  974240102                    Cilaos        H   367.370085   284.191953
# 49634  974240103                    Cilaos        H   149.522595   128.728062
# 49635  974240104                    Cilaos        H   211.906195   183.189935
#
# ...

# %%
popHFIR_H_new.to_csv('IRIS_population/IRIS_population_HF_IR_Hab.csv')
popIR_H_new.to_csv('IRIS_population/IRIS_population_IR_Hab.csv')
